# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Dataset: CO2 Emissions by Country 2000-2022
# Source: Our World in Data (https://ourworldindata.org/co2-emissions)
df = pd.read_csv('/content/co2_emissions.csv')
print(f"Loaded: {len(df)} rows | Countries: {df['Country'].nunique()} | Years: {df['Year'].min()}-{df['Year'].max()}")
print(df.head())
# Out:
# Loaded: 345 rows | Countries: 15 | Years: 2000-2022
#          Country         Region  Year  CO2_Mt  CO2_per_capita
# 0  United States  North America  2000  5857.6            1.32
# 1  United States  North America  2001  5724.0            1.26
# 2  United States  North America  2002  5652.8            1.11
# 3  United States  North America  2003  5592.8            1.29
# 4  United States  North America  2004  5743.2            1.12

# %%
print("Countries:", df['Country'].unique())
print("\nCO2 range:", df['CO2_Mt'].min(), "to", df['CO2_Mt'].max(), "Mt")
print("\nRegional averages (2022):")
print(df[df['Year']==2022].groupby('Region')['CO2_Mt'].mean().sort_values(ascending=False).round(1))
# Out:
# Countries: ['United States' 'China' 'India' 'Germany' 'United Kingdom' 'France'
#  'Brazil' 'Japan' 'Canada' 'Australia' 'South Korea' 'Russia'
#  'South Africa' 'Mexico' 'Indonesia']
#
# CO2 range: 125.3 to 12409.5 Mt
#
# Regional averages (2022):
# Region
# Asia             3531.1
# North America    2393.8
# Latin America     629.2
# Africa            534.4
# Europe            496.5
# Oceania           493.7
# Name: CO2_Mt, dtype: float64

# %% [markdown]
# Task 1 — Multi-Series Line Chart with Highlight
# What to build: A line chart showing CO2 emissions over time for all Asian countries in the dataset, with one country highlighted.
#
# Requirements:
#
# All countries shown (for context), but only one highlighted in colour — your choice which
# All other lines in grey (#DDDDDD), thinner
# Highlighted country labelled directly at the end of its line (not in a legend)
# Insight title that names the highlighted country and its story
#
# 💡 df[df['Region'] == 'Asia'] to filter; use go.Figure() with a loop for per-country control

# %%
# Filter Asia
asia = df[df['Region'] == 'Asia']

# List of Asian countries
countries = asia['Country'].unique()

# Choose highlighted country
highlight = "China"

fig = go.Figure()

# Add grey lines for all Asian countries
for c in countries:
    country_df = asia[asia['Country'] == c]
    fig.add_trace(go.Scatter(
        x=country_df['Year'],
        y=country_df['CO2_Mt'],
        mode='lines',
        line=dict(color='#DDDDDD', width=1),
        showlegend=False,
        hovertemplate=c + "<br>Year: %{x}<br>CO₂: %{y} Mt"
    ))

# Add highlighted country (China)
highlight_df = asia[asia['Country'] == highlight]
fig.add_trace(go.Scatter(
    x=highlight_df['Year'],
    y=highlight_df['CO2_Mt'],
    mode='lines+text',
    line=dict(color='#800080', width=3),
    text=[None]*(len(highlight_df)-1) + [highlight],
    textposition='middle right',
    textfont=dict(color='#800080', size=14),
    showlegend=False,
    hovertemplate=highlight + "<br>Year: %{x}<br>CO₂: %{y} Mt"
))

# Layout
fig.update_layout(
    title="China’s Rapid Industrial Rise Drove Asia’s CO₂ Emissions Surge (2000–2022)",
    xaxis_title="Year",
    yaxis_title="CO₂ Emissions (Mt)",
    template="simple_white",
    height=550
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02bfddf7-105e-4721-8750-06761215ae97" class="plotly-graph-div" style="height:550px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02bfddf7-105e-4721-8750-06761215ae97")) {                    Plotly.newPlot(                        "02bfddf7-105e-4721-8750-06761215ae97",                        [{"hovertemplate":"China\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#DDDDDD","width":1},"mode":"lines","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[3513.8,3951.7,4312.0,4691.9,5078.9,5467.8,5974.0,6322.7,6673.0,7052.6,7542.8,7972.2,8365.2,8641.3,9078.4,9466.5,9887.0,10356.9,10794.9,11125.3,11454.8,11897.5,12409.5],"type":"scatter"},{"hovertemplate":"India\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#DDDDDD","width":1},"mode":"lines","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[901.6,974.6,1056.0,1146.4,1205.4,1291.0,1396.5,1465.9,1541.7,1637.4,1687.4,1774.1,1865.3,1944.7,1994.5,2092.4,2177.1,2267.3,2344.6,2418.7,2465.5,2579.5,2661.1],"type":"scatter"},{"hovertemplate":"Japan\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#DDDDDD","width":1},"mode":"lines","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[1165.7,1219.6,1135.5,1131.4,1151.1,1126.7,1100.8,1133.1,1050.3,1061.4,1064.1,1041.7,1005.1,990.9,1010.4,996.6,967.4,925.1,916.6,914.5,902.8,898.1,865.1],"type":"scatter"},{"hovertemplate":"South Korea\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#DDDDDD","width":1},"mode":"lines","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[438.1,481.5,490.6,490.8,494.6,537.2,539.0,566.1,570.0,585.4,595.9,620.6,631.1,649.6,646.2,686.5,704.0,706.0,738.5,750.8,755.8,777.3,789.5],"type":"scatter"},{"hovertemplate":"Indonesia\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#DDDDDD","width":1},"mode":"lines","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[382.8,400.4,430.7,453.8,482.6,501.9,533.0,551.8,586.6,602.5,614.5,647.3,680.1,717.7,736.3,738.2,768.8,813.7,834.8,872.3,876.5,898.5,930.5],"type":"scatter"},{"hovertemplate":"China\u003cbr\u003eYear: %{x}\u003cbr\u003eCO₂: %{y} Mt","line":{"color":"#800080","width":3},"mode":"lines+text","showlegend":false,"text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"China"],"textfont":{"color":"#800080","size":14},"textposition":"middle right","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[3513.8,3951.7,4312.0,4691.9,5078.9,5467.8,5974.0,6322.7,6673.0,7052.6,7542.8,7972.2,8365.2,8641.3,9078.4,9466.5,9887.0,10356.9,10794.9,11125.3,11454.8,11897.5,12409.5],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecol ...

# %% [markdown]
# Task 2 — Slopegraph: Regional Change 2000 vs 2022
# What to build: A slopegraph comparing average regional CO2 emissions between 2000 and 2022.
#
# Requirements:
#
# One line per region (not per country — aggregate first)
# Colour: regions that increased = one colour; decreased = another
# Values labelled at both ends of each line
# No y-axis tick labels (the endpoint labels make them redundant)
# Insight title stating which regions moved most
#
#
# 💡 df.groupby(['Region','Year'])['CO2_Mt'].mean().reset_index() then filter to 2000 and 2022 **bold text**

# %%
# Aggregate by Region and Year
regional = (
    df.groupby(['Region', 'Year'])['CO2_Mt']
      .mean()
      .reset_index()
)

# Filter only 2000 and 2022
subset = regional[regional['Year'].isin([2000, 2022])]

# Pivot for easier plotting
pivot = subset.pivot(index='Region', columns='Year', values='CO2_Mt').reset_index()

# Determine color: increase = green, decrease = red
pivot['color'] = pivot.apply(lambda row: '#FFFF00' if row[2022] > row[2000] else '#0000FF', axis=1)

fig = go.Figure()

# Add one line per region
for _, row in pivot.iterrows():
    fig.add_trace(go.Scatter(
        x=[2000, 2022],
        y=[row[2000], row[2022]],
        mode='lines+text',
        line=dict(color=row['color'], width=3),
        text=[f"{row[2000]:.1f}", f"{row[2022]:.1f}"],
        textposition=['middle left', 'middle right'],
        textfont=dict(size=12, color=row['color']),
        showlegend=False,
        hovertemplate=(
            f"{row['Region']}<br>"
            "Year %{x}: %{y:.1f} Mt"
        )
    ))

# Add region labels separately (cleaner)
for _, row in pivot.iterrows():
    fig.add_trace(go.Scatter(
        x=[1999.5],  # left label
        y=[row[2000]],
        text=[row['Region']],
        mode='text',
        textposition='middle right',
        showlegend=False,
        textfont=dict(size=13)
    ))

# Layout
fig.update_layout(
    title="Asia Shows the Largest CO₂ Surge, While Europe Declines Sharply (2000–2022)",
    xaxis=dict(title="", showticklabels=False),
    yaxis=dict(title="CO₂ Emissions (Mt)", showticklabels=False),
    template="simple_white",
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dca096a9-98e5-4751-84a3-bfe7f76e5147" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dca096a9-98e5-4751-84a3-bfe7f76e5147")) {                    Plotly.newPlot(                        "dca096a9-98e5-4751-84a3-bfe7f76e5147",                        [{"hovertemplate":"Africa\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#FFFF00","width":3},"mode":"lines+text","showlegend":false,"text":["425.4","534.4"],"textfont":{"color":"#FFFF00","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[425.4,534.4],"type":"scatter"},{"hovertemplate":"Asia\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#FFFF00","width":3},"mode":"lines+text","showlegend":false,"text":["1280.4","3531.1"],"textfont":{"color":"#FFFF00","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[1280.4,3531.1400000000003],"type":"scatter"},{"hovertemplate":"Europe\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#0000FF","width":3},"mode":"lines+text","showlegend":false,"text":["834.9","496.5"],"textfont":{"color":"#0000FF","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[834.925,496.5],"type":"scatter"},{"hovertemplate":"Latin America\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#FFFF00","width":3},"mode":"lines+text","showlegend":false,"text":["419.9","629.1"],"textfont":{"color":"#FFFF00","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[419.85,629.15],"type":"scatter"},{"hovertemplate":"North America\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#0000FF","width":3},"mode":"lines+text","showlegend":false,"text":["3223.6","2393.8"],"textfont":{"color":"#0000FF","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[3223.6000000000004,2393.7999999999997],"type":"scatter"},{"hovertemplate":"Oceania\u003cbr\u003eYear %{x}: %{y:.1f} Mt","line":{"color":"#FFFF00","width":3},"mode":"lines+text","showlegend":false,"text":["378.4","493.7"],"textfont":{"color":"#FFFF00","size":12},"textposition":["middle left","middle right"],"x":[2000,2022],"y":[378.4,493.7],"type":"scatter"},{"mode":"text","showlegend":false,"text":["Africa"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[425.4],"type":"scatter"},{"mode":"text","showlegend":false,"text":["Asia"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[1280.4],"type":"scatter"},{"mode":"text","showlegend":false,"text":["Europe"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[834.925],"type":"scatter"},{"mode":"text","showlegend":false,"text":["Latin America"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[419.85],"type":"scatter"},{"mode":"text","showlegend":false,"text":["North America"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[3223.6000000000004],"type":"scatter"},{"mode":"text","showlegend":false,"text":["Oceania"],"textfont":{"size":13},"textposition":"middle right","x":[1999.5],"y":[378.4],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","sta ...
